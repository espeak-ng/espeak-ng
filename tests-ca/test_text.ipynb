# %%
import pandas as pd
import re

# %%
var = "ca-va"

# %%
file = "data/text.txt"
text = open(file, "r").read()

# %%
def transcript(src_text, var):
    cmd = f'../src/espeak-ng "{src_text}" --ipa -v {var} -q'
    output = str(os.popen(cmd).read())[:-1]
    output = output.replace("ɡ", "g")
    return output

# %%
transcription = transcript(text, var)
transcript_words = re.split('\W+', transcription)

# %%
gs = 'data/text_gs_' + var + '.csv'
df = pd.read_csv(gs, sep="\t")

# %%
df["transcription"] = transcript_words[:len(df)]

# %%
df["eval"] = df["GS"] == df["transcription"]

# %%
df.loc[df['eval'] == False]
# Out:
#      Unnamed: 0             text                   GS  \
# 17           17          dotzena             ðodzˈɛna
# 28           28               es                   ez
# 31           31           darrer              daɾɾˈeɾ
# 49           49               es                   es
# 58           58              per                  per
# 70           70               en                   an
# 75           75               un                   uɱ
# 81           81    holísticament        ol,istikamˈen
# 115         115               un                   un
# 123         123               Es                   es
# 127         127              per                  per
# 135         135     Vint-i-tresè        v,int,itɾezˈɛ
# 154         154       l’indonesi          lˌindonˈɛzi
# 156         156              462  komakwˌa tɾesˈents
# 157         157              NaN        seiʃˌantað'os
# 160         160        tanmateix          tˌammatˈejʃ
# 163         163               un                  'uɱ
# 181         181            feina               fˈejna
# 182         182              per                  per
# 199         199            menes               mˈenez
# 205         205              per                  per
# 212         212              per                  per
# 215         215              Per                  per
# 226         226         purament           p,uɾamˈent
# 229         229               es                   ez
# 235         235         solament            s,olamˈen
# 242         242               en                   aŋ
# 246         246           inclou              iŋklˈɔw
# 249         249         elements            elem'ents
# 255         255             fins                fˈinz
# 258         258      tecnològics        tegnolˈɔdʒigz
# 262         262               en                   aŋ
# 270         270         especial            espesiˈal
# 282         282  desenvolupament     dezemvolupam'ent
#
#                                      transtext             segre  \
# 17                         d o t . s ˈɛ . n a           Dodz'ena
# 28                                        e s                 ez
# 31                               d a . r ˈe ɾ            darr'er
# 49                                        e s                 es
# 58                                      p e ɾ                per
# 70                                        e n                 en
# 75                                       ˈu n                 um
# 81          o . l ˈi s . t i . k a . m ˈe n t      ol,istikam'en
# 115                                      ˈu n                'um
# 123                                       e s                 es
# 127                                     p e ɾ                per
# 135                  b ˈi n t ˈi t ɾ e . s ˈɛ       v,intitrez'E
# 154                  l i n . d o . n ˈɛ . s i         lindon'Ezi
# 156      k ˈo . m a k w ˌa . t ɾ e s ˈe n t s                NaN
# 157                                        NaN               NaN
# 160                    t a m . m a . t ˈe j ʃ         tammat'ejS
# 163                                      ˈu n                 um
# 181                              f ˈɛ j . n a             f'ejna
# 182                                     p e ɾ                per
# 199                              m ˈɛ . n e s             m'enez
# 205                                     p e ɾ                per
# 212                                     p e ɾ                per
# 215                                     p e ɾ                per
# 226                     p ˈu . ɾ a . m ˈe n t          p,uram'en
# 229                                       e s                 ez
# 235                     s ˈɔ . l a . m ˈe n t         s,olam'ent
# 242                                       e n                 eN
# 246                            i n . k l ˈɔ w           iNkl'Ouw
# 249                      e . l e . m ˈe n t s            elem'en
# 255                                  f ˈi n s              f'inz
# 258            t e k . n o . l ˈɔ t . ʃ i k s      tegnol'OdZigz
# 262                                       e n                 eN
# 270                    a s . p e . s i . ˈa l          aspesi'al
# 282  d e . z e m . b o . l u . p a . m ˈe n t   dezemvolupam'ent
#
#        transcription   eval
# 17           ðozˈɛna  False
# 28                az  False
# 31            darˈeɾ  False
# 49                as  False
# 58               pər  False
# 70                en  False
# 75                wɱ  False
# 81     olˈistikamˈen  False
# 115               wn  False
# 123               as  False
# 127              pər  False
# 135    vˈintˈitɾezˈɛ  False
# 154      lˌindonˈezi  False
# 156        komasˌens  False
# 157    seiʃˌantaðˌos  False
# 160      tˌammətˈetʃ  False
# 163               wɱ  False
# 181           fˈɛjna  False
# 182              pər  False
# 199           mˈɛnez  False
# 205              pər  False
# 212              pər  False
# 215              pər  False
# 226        pˈuɾamˈen  False
# 229               az  False
# 235        sˈɔlamˈen  False
# 242               eŋ  False
# 246          iŋklˈow  False
# 249         ələmˈens  False
# 255            fˈins  False
# 258    teŋnolˈɔdʒiks  False
# 262               eŋ  False
# 270        aspesiˈal  False
# 282  dəzəmbulupəmˈen  False

# %%
result = "results/results_" + var + ".csv"
df.to_csv(result, sep="\t")
